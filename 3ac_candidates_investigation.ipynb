# %%
import pandas as pd
import numpy as np

# %%
c_pbc = pd.read_csv('pbc_tot_rt.csv', index_col=0) #candidates from total pbc at room temperature
u_minus = pd.read_csv('pbc_diff_unknown_minus.csv', index_col=0) #unknowns from pbc difference (<=-4)
u_plus = pd.read_csv('pbc_diff_unknown_plus.csv', index_col=0) #unknowns from pbc difference (>=12)
c_small = pd.read_csv('first_peak_candidates_01.csv', index_col=0) #candidates from first peak
c = pd.read_csv('first_peak_candidates.csv', index_col=0) #candidates from first peak
c_dos = pd.read_csv('circle_dos_fv.csv', index_col=0) #candidates within the circle

# %%
data = pd.read_csv('stoich_data.csv') #Kasper's data obtained from m3gnet
data.rename(columns={'Unnamed: 0': 'material_id'}, inplace=True)

# %% [markdown]
# ## Candidates from the Li first peak descriptor

# %%
len(c_small)
# Out:
# 39

# %%
match = pd.merge(c, data, on=['material_id'], how='inner')
match.sort_values('0.2', inplace=True)
match
# Out:
#    material_id formula_pretty_reduced       0.2       0.5       100       200  \
# 6    mp-985582                Li6PS5I -4.857220 -4.857220       NaN       NaN
# 1    mp-559708             Li6ZrBeF12 -3.469315       NaN       NaN       NaN
# 10    mp-30301                 LiClO4 -2.821064 -2.821064       NaN       NaN
# 8    mp-776108                 LiNbO3 -2.714737 -2.714737       NaN       NaN
# 3    mp-696129           Li10Si(PS6)2 -2.550960       NaN  0.000002  0.000006
# 2    mp-753327               LiSiBiO4 -2.389002 -2.389002       NaN       NaN
# 11     mp-6783                NaLiSO4 -2.349638       NaN       NaN       NaN
# 4    mp-696128           Li10Ge(PS6)2 -2.276746       NaN       NaN  0.000006
# 5    mp-676650                Li6Br3N -2.260874       NaN       NaN       NaN
# 9    mp-675488                 Li6I3N -1.557847       NaN       NaN       NaN
# 0    mp-557962                SrLiBS3 -1.514451       NaN       NaN       NaN
# 7      mp-9018                LiCdPO4 -1.096051       NaN       NaN       NaN
#
#          300       400       500       600  ...      1400  1500      1600  \
# 6        NaN  0.000006       NaN  0.000016  ...       NaN   NaN       NaN
# 1        NaN       NaN       NaN       NaN  ...  0.000078   NaN       NaN
# 10       NaN       NaN       NaN       NaN  ...       NaN   NaN       NaN
# 8        NaN       NaN       NaN       NaN  ...       NaN   NaN       NaN
# 3   0.000015  0.000027  0.000046  0.000066  ...       NaN   NaN       NaN
# 2        NaN       NaN       NaN       NaN  ...       NaN   NaN  0.000006
# 11       NaN       NaN       NaN       NaN  ...       NaN   NaN       NaN
# 4   0.000012  0.000027  0.000051       NaN  ...       NaN   NaN       NaN
# 5        NaN       NaN       NaN       NaN  ...       NaN   NaN       NaN
# 9        NaN       NaN       NaN       NaN  ...       NaN   NaN       NaN
# 0        NaN       NaN       NaN       NaN  ...       NaN   NaN       NaN
# 7        NaN       NaN       NaN       NaN  ...       NaN   NaN       NaN
#
#         1700  1800  1900  2000      2100      2200      2300
# 6        NaN   NaN   NaN   NaN       NaN       NaN       NaN
# 1        NaN   NaN   NaN   NaN       NaN       NaN       NaN
# 10       NaN   NaN   NaN   NaN       NaN       NaN       NaN
# 8        NaN   NaN   NaN   NaN  0.000004  0.000003  0.000005
# 3        NaN   NaN   NaN   NaN       NaN       NaN       NaN
# 2   0.000028   NaN   NaN   NaN       NaN       NaN       NaN
# 11       NaN   NaN   NaN   NaN       NaN       NaN       NaN
# 4        NaN   NaN   NaN   NaN       NaN       NaN       NaN
# 5        NaN   NaN   NaN   NaN       NaN       NaN       NaN
# 9        NaN   NaN   NaN   NaN       NaN       NaN       NaN
# 0        NaN   NaN   NaN   NaN       NaN       NaN       NaN
# 7        NaN   NaN   NaN   NaN       NaN       NaN       NaN
#
# [12 rows x 27 columns]

# %%
temp = list(range(100, 2300+1, 100))

for i in range(len(match)):
    mat = match.at[i, 'formula_pretty_reduced']
    print(mat+' conducts at')
    diff = []
    for j, t in enumerate(temp):
        d = match.at[i, str(t)]
        diff.append(d)
        if np.isnan(d) == False:
            print(str(temp[j])+'K: '+str(d))
    if np.isnan(np.array(diff)).all() == True:
            print('never')
# Out:
# SrLiBS3 conducts at
# 700K: 1.51e-05
# 800K: 4.269e-05
# Li6ZrBeF12 conducts at
# 1100K: 2.462e-06
# 1200K: 1.236e-05
# 1300K: 6.22e-05
# 1400K: 7.832e-05
# LiSiBiO4 conducts at
# 1600K: 5.577e-06
# 1700K: 2.82e-05
# Li10Si(PS6)2 conducts at
# 100K: 1.675e-06
# 200K: 5.589e-06
# 300K: 1.502e-05
# 400K: 2.666e-05
# 500K: 4.641e-05
# 600K: 6.581e-05
# 700K: 0.0001015
# 800K: 0.0001337
# Li10Ge(PS6)2 conducts at
# 200K: 5.563e-06
# 300K: 1.205e-05
# 400K: 2.688e-05
# 500K: 5.15e-05
# Li6Br3N conducts at
# 1000K: 1.213e-06
# 1100K: 1.86e-05
# Li6PS5I conducts at
# 400K: 6.423e-06
# 600K: 1.555e-05
# 700K: 8.851e-05
# 800K: 0.0001198
# LiCdPO4 conducts at
# never
# LiNbO3 conducts at
# 2100K: 3.645e-06
# 2200K: 2.67e-06
# 2300K: 4.875e-06
# Li6I3N conducts at
# never
# LiClO4 conducts at
# never
# NaLiSO4 conducts at
# never

# %% [markdown]
# 8 conductors out 12 materials (4 insulators, NaLiSO4 was already known from the database). 3 out of 8 conductors were already known from the database, so we have found 5 conductors that were not in the database previously: SrLiBS3, Li6ZrBeF12, LiSiBiO4, Li6Br3N, and LiNbO3.

# %% [markdown]
# #### Review of the literature

# %% [markdown]
# SrLiBS3: found in https://www.nature.com/articles/nmat4369 but only part of similarity analysis between screened ICSD structures containing Li and S to a bcc anion framework. No reports of conductivity, but they suggest that bcc anion framework gives superior conductivity.

# %% [markdown]
# Li6ZrBeF12: nothing found, apart from 1964 report of the crystal structure.

# %% [markdown]
# LiSiBiO4: nothing found.

# %% [markdown]
# Li6Br3N: nothing found.

# %% [markdown]
# LiNbO3: several reports of ionic conductivity including https://pubs.aip.org/aip/jap/article-abstract/49/9/4808/169072/Ionic-conductivity-of-quenched-alkali-niobate-and?redirectedFrom=fulltext (amorphous), https://chemistry-europe.onlinelibrary.wiley.com/doi/full/10.1002/celc.201901208?casa_token=8ZKZJ0BxO_QAAAAA%3A7SU353RBfpOi3cD-6CTS6B8XjIwVHS6s__fbxfkupEMG27fWjncUm8QN-IWH9KHx7rfCxJB2Owley_fe and https://www.sciencedirect.com/science/article/pii/S1388248107000719 (used as coating for cathodes), https://www.sciencedirect.com/science/article/pii/S092151070300597X (electrolyte thin films), https://link.springer.com/article/10.1557/JMR.1991.0851.

# %% [markdown]
# ### Not investigated

# %%
no_match = pd.merge(c, data, on=['material_id'], how='outer', indicator=True)

no_match = no_match[no_match['_merge']=='left_only']

no_match.sort_values('0.2', inplace=True)
no_match
# Out:
#    material_id formula_pretty_reduced       0.2       0.5  100  200  300  400  \
# 21   mp-989536               Cs2LiNF6 -9.582517 -9.582517  NaN  NaN  NaN  NaN
# 2    mp-772535              LiNb13O33 -7.303432 -7.303432  NaN  NaN  NaN  NaN
# 6     mp-39387             SrLiTa2O6F -4.813808 -4.813808  NaN  NaN  NaN  NaN
# 3    mp-849779             LiSi6BiO14 -4.272276 -4.272276  NaN  NaN  NaN  NaN
# 18   mp-585305            Li9Bi3P8O29 -3.948464 -3.948464  NaN  NaN  NaN  NaN
# 20     mp-6478               LiTaGeO5 -2.961831       NaN  NaN  NaN  NaN  NaN
# 12   mp-555002            LiEr2S2O8F3 -2.804818 -2.804818  NaN  NaN  NaN  NaN
# 0    mp-557969            LiLa2S2O8F3 -2.405614 -2.405614  NaN  NaN  NaN  NaN
# 15   mp-560058            Li9Ga3P8O29 -2.157863       NaN  NaN  NaN  NaN  NaN
# 5     mp-13182              Li2TiGeO5 -2.125617       NaN  NaN  NaN  NaN  NaN
# 22    mp-40189             BaLiLaTeO6 -1.945770 -1.945770  NaN  NaN  NaN  NaN
# 19   mp-756432           Li2Ti(TeO4)3 -1.796717       NaN  NaN  NaN  NaN  NaN
# 17     mp-6011             Ba4LiMo2N7 -1.269050       NaN  NaN  NaN  NaN  NaN
# 13   mp-552663              LiScAs2O7 -1.097430       NaN  NaN  NaN  NaN  NaN
#
#     500  600  ...  1500  1600  1700  1800  1900  2000  2100  2200  2300  \
# 21  NaN  NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN  NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 6   NaN  NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN  NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 18  NaN  NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 20  NaN  NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 12  NaN  NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 0   NaN  NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 15  NaN  NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 5   NaN  NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 22  NaN  NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 19  NaN  NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 17  NaN  NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 13  NaN  NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#        _merge
# 21  left_only
# 2   left_only
# 6   left_only
# 3   left_only
# 18  left_only
# 20  left_only
# 12  left_only
# 0   left_only
# 15  left_only
# 5   left_only
# 22  left_only
# 19  left_only
# 17  left_only
# 13  left_only
#
# [14 rows x 28 columns]

# %% [markdown]
# Li9Ga3P8O29, Li9Bi3P8O29, Cs2LiNF6 have Li fraction above 0.1 and do not contain potentially redox active transition metals.

# %% [markdown]
# ## Candidates/Unknowns from phonon band-centre

# %%
len(c_pbc)
# Out:
# 16

# %%
match = pd.merge(c_pbc, data, on=['material_id'], how='inner')
match.sort_values('298_tot', inplace=True)
match
# Out:
#   material_id formula_pretty_reduced   298_tot       100       200       300  \
# 1     mp-6597                CsLiSO4  1.023723       NaN       NaN       NaN
# 5    mp-28237                RbLiBr2  1.395309       NaN       NaN       NaN
# 0   mp-559715            Li2Cd(PO3)4  1.512659       NaN       NaN       NaN
# 6    mp-23057                CsLiBr2  1.645601       NaN       NaN       NaN
# 3   mp-696129           Li10Si(PS6)2  1.880669  0.000002  0.000006  0.000015
# 4   mp-696128           Li10Ge(PS6)2  1.963787       NaN  0.000006  0.000012
# 2    mp-31488                Li3NbO4  1.982970       NaN       NaN       NaN
#
#         400       500       600       700  ...      1400  1500  1600  1700  \
# 1       NaN       NaN       NaN       NaN  ...       NaN   NaN   NaN   NaN
# 5       NaN       NaN       NaN       NaN  ...       NaN   NaN   NaN   NaN
# 0       NaN       NaN       NaN       NaN  ...  0.000011   NaN   NaN   NaN
# 6       NaN       NaN       NaN       NaN  ...       NaN   NaN   NaN   NaN
# 3  0.000027  0.000046  0.000066  0.000102  ...       NaN   NaN   NaN   NaN
# 4  0.000027  0.000051       NaN       NaN  ...       NaN   NaN   NaN   NaN
# 2       NaN       NaN       NaN       NaN  ...       NaN   NaN   NaN   NaN
#
#    1800  1900  2000  2100  2200  2300
# 1   NaN   NaN   NaN   NaN   NaN   NaN
# 5   NaN   NaN   NaN   NaN   NaN   NaN
# 0   NaN   NaN   NaN   NaN   NaN   NaN
# 6   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN
#
# [7 rows x 26 columns]

# %%
temp = list(range(100, 2300+1, 100))

for i in range(len(match)):
    mat = match.at[i, 'formula_pretty_reduced']
    print(mat+' conducts at')
    diff = []
    for j, t in enumerate(temp):
        d = match.at[i, str(t)]
        diff.append(d)
        if np.isnan(d) == False:
            print(str(temp[j])+'K: '+str(d))
    if np.isnan(np.array(diff)).all() == True:
            print('never')
# Out:
# Li2Cd(PO3)4 conducts at
# 1400K: 1.112e-05
# CsLiSO4 conducts at
# never
# Li3NbO4 conducts at
# never
# Li10Si(PS6)2 conducts at
# 100K: 1.675e-06
# 200K: 5.589e-06
# 300K: 1.502e-05
# 400K: 2.666e-05
# 500K: 4.641e-05
# 600K: 6.581e-05
# 700K: 0.0001015
# 800K: 0.0001337
# Li10Ge(PS6)2 conducts at
# 200K: 5.563e-06
# 300K: 1.205e-05
# 400K: 2.688e-05
# 500K: 5.15e-05
# RbLiBr2 conducts at
# never
# CsLiBr2 conducts at
# never

# %% [markdown]
# Only one new ionic conductor discovered: Li2Cd(PO3)4.

# %% [markdown]
# ### Literature review

# %% [markdown]
# Li2Cd(PO3)4: seems to be studied for photocatalytic applications.

# %% [markdown]
# ## Unknowns from phonon band-centre difference

# %% [markdown]
# ### Negative difference

# %%
len(u_minus)
# Out:
# 57

# %%
match = pd.merge(u_minus, data, on=['material_id'], how='inner')

match.sort_values('d_fav', inplace=True)
match
# Out:
#    material_id formula_pretty_reduced      d_fav  100  200  300       400  \
# 6     mp-10814                SrLiBO3 -13.702625  NaN  NaN  NaN       NaN
# 3      mp-6499                BaLiBO3 -11.610104  NaN  NaN  NaN       NaN
# 11   mp-559766                Cs3LiF4  -8.510013  NaN  NaN  NaN       NaN
# 5    mp-553988                Cs2LiF3  -6.343473  NaN  NaN  NaN       NaN
# 10   mp-559612                   KLiO  -5.636493  NaN  NaN  NaN       NaN
# 8    mp-774907                KLiZnS2  -5.456659  NaN  NaN  NaN       NaN
# 14   mp-571390               Cs2LiCl3  -5.344040  NaN  NaN  NaN       NaN
# 13   mp-570756              Cs3Li2Cl5  -5.326511  NaN  NaN  NaN       NaN
# 0    mp-569238                Cs3LiI4  -5.029538  NaN  NaN  NaN  0.000008
# 12    mp-28243                RbLiCl2  -4.878440  NaN  NaN  NaN       NaN
# 4    mp-556237                 KLiYF5  -4.340992  NaN  NaN  NaN       NaN
# 2    mp-569055                CsLi2I3  -4.337859  NaN  NaN  NaN       NaN
# 1    mp-558728               Cs3Li2F5  -4.290156  NaN  NaN  NaN       NaN
# 9     mp-20310                LiInSe2  -4.229923  NaN  NaN  NaN  0.000002
# 7    mp-571409              Cs2Li3Br5  -4.051751  NaN  NaN  NaN       NaN
#
#          500  600       700  ...  1400  1500  1600      1700  1800  1900  \
# 6        NaN  NaN       NaN  ...   NaN   NaN   NaN       NaN   NaN   NaN
# 3        NaN  NaN       NaN  ...   NaN   NaN   NaN       NaN   NaN   NaN
# 11       NaN  NaN       NaN  ...   NaN   NaN   NaN       NaN   NaN   NaN
# 5        NaN  NaN       NaN  ...   NaN   NaN   NaN       NaN   NaN   NaN
# 10       NaN  NaN       NaN  ...   NaN   NaN   NaN  0.000032   NaN   NaN
# 8        NaN  NaN       NaN  ...   NaN   NaN   NaN       NaN   NaN   NaN
# 14       NaN  NaN       NaN  ...   NaN   NaN   NaN       NaN   NaN   NaN
# 13       NaN  NaN       NaN  ...   NaN   NaN   NaN       NaN   NaN   NaN
# 0   0.000036  NaN       NaN  ...   NaN   NaN   NaN       NaN   NaN   NaN
# 12       NaN  NaN       NaN  ...   NaN   NaN   NaN       NaN   NaN   NaN
# 4        NaN  NaN       NaN  ...   NaN   NaN   NaN       NaN   NaN   NaN
# 2   0.000036  NaN       NaN  ...   NaN   NaN   NaN       NaN   NaN   NaN
# 1        NaN  NaN       NaN  ...   NaN   NaN   NaN       NaN   NaN   NaN
# 9   0.000034  NaN       NaN  ...   NaN   NaN   NaN       NaN   NaN   NaN
# 7        NaN  NaN  0.000005  ...   NaN   NaN   NaN       NaN   NaN   NaN
#
#     2000      2100      2200      2300
# 6    NaN       NaN       NaN       NaN
# 3    NaN  0.000003  0.000002  0.000003
# 11   NaN       NaN       NaN       NaN
# 5    NaN       NaN       NaN       NaN
# 10   NaN       NaN       NaN       NaN
# 8    NaN       NaN       NaN       NaN
# 14   NaN       NaN       NaN       NaN
# 13   NaN       NaN       NaN       NaN
# 0    NaN       NaN       NaN       NaN
# 12   NaN       NaN       NaN       NaN
# 4    NaN       NaN       NaN       NaN
# 2    NaN       NaN       NaN       NaN
# 1    NaN       NaN       NaN       NaN
# 9    NaN       NaN       NaN       NaN
# 7    NaN       NaN       NaN       NaN
#
# [15 rows x 26 columns]

# %%
temp = list(range(100, 2300+1, 100))

for i in range(len(match)):
    mat = match.at[i, 'formula_pretty_reduced']
    print(mat+' conducts at')
    diff = []
    for j, t in enumerate(temp):
        d = match.at[i, str(t)]
        diff.append(d)
        if np.isnan(d) == False:
            print(str(temp[j])+'K: '+str(d))
    if np.isnan(np.array(diff)).all() == True:
            print('never')
# Out:
# Cs3LiI4 conducts at
# 400K: 8.412e-06
# 500K: 3.583e-05
# Cs3Li2F5 conducts at
# never
# CsLi2I3 conducts at
# 500K: 3.623e-05
# BaLiBO3 conducts at
# 2100K: 2.621e-06
# 2200K: 1.627e-06
# 2300K: 2.674e-06
# KLiYF5 conducts at
# 1300K: 2.653e-06
# Cs2LiF3 conducts at
# never
# SrLiBO3 conducts at
# never
# Cs2Li3Br5 conducts at
# 700K: 4.833e-06
# 800K: 4.818e-05
# KLiZnS2 conducts at
# never
# LiInSe2 conducts at
# 400K: 2.306e-06
# 500K: 3.39e-05
# KLiO conducts at
# 1700K: 3.174e-05
# Cs3LiF4 conducts at
# never
# RbLiCl2 conducts at
# never
# Cs3Li2Cl5 conducts at
# 1100K: 6.248e-06
# Cs2LiCl3 conducts at
# never

# %% [markdown]
# 8 new conductors out of 15 materials (7 insulators): Cs3LiI4, CsLi2I3, BaLiBO3, KLiYF5, Cs2Li3Br5, LiInSe2, KLiO, Cs3Li2Cl5.
# In particular, Cs3LiI4, CsLi2I3, and LiInSe2 all show diffusion at 500K. Cs3LiI4 and LiInSe2 diffuse at 400K too.

# %% [markdown]
# #### Literature review

# %% [markdown]
# Cs3LiI4 (conducts at low T): mentioned in https://www.cell.com/iscience/pdf/S2589-0042(19)30173-7.pdf (phonon band-centre high-throughput screening), https://www.proquest.com/docview/2455593364?pq-origsite=gscholar&fromopenview=true (stable electrodeposition with Li metal anode high-throughput screening).

# %% [markdown]
# CsLi2I3 (conducts at low T): mentioned in https://www.cell.com/iscience/pdf/S2589-0042(19)30173-7.pdf (phonon band-centre high-throughput screening).

# %% [markdown]
# BaLiBO3: seems mostly known for its luminescent properties, nothing found on ionic conduction.

# %% [markdown]
# KLiYF5: found as two of the most promising SSE candidates according to a high-throughput workflow including electrochemical stability window, oxidation potentials, compatibility with cathodes, etc... https://doi.org/10.1002/aenm.202201808.

# %% [markdown]
# Cs2Li3Br5: mentioned in https://www.cell.com/iscience/pdf/S2589-0042(19)30173-7.pdf (phonon band-centre high-throughput screening).

# %% [markdown]
# LiInSe2: suggested as an anode materials (https://www.sciencedirect.com/science/article/pii/S0013468619313982), coated with a carbon layer (https://doi.org/10.1002/celc.201901438).

# %% [markdown]
# KLiO: nothing found.

# %% [markdown]
# Cs3Li2Cl5: synthesis reports.

# %% [markdown]
# ### Positive difference

# %%
print(len(u_plus))
u_plus
# Out:
# 24
#     material_id formula_pretty_reduced      d_fav
# 29    mp-941221                Li(BH)5  25.191964
# 34    mp-976291                 LiAlH4  15.563288
# 45    mp-977298                 LiBeH3  16.014076
# 55    mp-556562           LiAsH6(OF2)3  19.732810
# 125   mp-638070                LiB13C2  14.258713
# 157   mp-697181             CsLi2(HO)3  12.925573
# 207   mp-504354             LiBi(PO3)4  12.201742
# 215   mp-866640               LiMgH6Ir  21.314584
# 277   mp-696057            LiMg4H13Os2  14.563998
# 290   mp-696949               Li3TeHO4  13.830019
# 305   mp-760502                LiH2ClO  20.667614
# 363   mp-571132            LiMg10AlH24  12.942469
# 366   mp-655591                LiB13C2  13.982584
# 400   mp-722890                Li3H6Ir  14.607115
# 442   mp-755891              CsLiH4SO5  14.601069
# 535   mp-698205              LiB(HO2)2  14.622052
# 586   mp-560246            LiUP(H4O5)2  16.650866
# 614   mp-570218                 LiBeH3  16.252526
# 616     mp-8204                LiAlB14  13.532448
# 662   mp-604147            Na2Li(H2N)3  28.537854
# 717   mp-643276              LiMg2H7Ru  15.424733
# 739   mp-733455                Li3H6Rh  13.772273
# 806   mp-977148                 LiBeH3  15.211447
# 837   mp-642740             CsLi(H2N)2  24.757322

# %%
match = pd.merge(u_plus, data, on=['material_id'], how='inner')
match
# Out:
# Empty DataFrame
# Columns: [material_id, formula_pretty_reduced, d_fav, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# ## Candidates from total DOS feature (clustering)

# %%
len(c_dos)
# Out:
# 49

# %%
match = pd.merge(c_dos, data, on=['material_id'], how='inner')
match
# Out:
#     Dimension 1  Dimension 2  Formula material_id  σ(RT)(S cm-1) Conductor?  \
# 0     24.065096   -10.606493   Li3ClO   mp-985585       0.000850        Yes
# 1     24.509417    -8.401900   Li2CN2     mp-9610            NaN    Unknown
# 2     23.155860    -8.094121      LiC     mp-1378            NaN    Unknown
# 3     27.408852   -12.948709     LiBr   mp-976280            NaN    Unknown
# 4     24.008133   -11.164456   BaLiF3    mp-10250            NaN    Unknown
# 5     21.869663   -11.471073     KLiS     mp-8430            NaN    Unknown
# 6     25.823454   -10.858885   Li3BrO    mp-28593       0.000001        Yes
# 7     22.198479    -9.591389  Li2ZrF6     mp-4002            NaN    Unknown
# 8     22.395422   -14.238488    RbLiS     mp-8751            NaN    Unknown
# 9     25.022707    -5.394366  LiSiBO4     mp-8874            NaN    Unknown
# 10    22.953873   -10.314582     LiN3     mp-2659            NaN    Unknown
# 11    22.239428    -7.620939      LiF     mp-1138            NaN    Unknown
#
#     100  200  300  400  ...      1400      1500      1600     1700      1800  \
# 0   NaN  NaN  NaN  NaN  ...       NaN       NaN       NaN      NaN  0.000003
# 1   NaN  NaN  NaN  NaN  ...       NaN       NaN       NaN      NaN       NaN
# 2   NaN  NaN  NaN  NaN  ...       NaN       NaN       NaN      NaN       NaN
# 3   NaN  NaN  NaN  NaN  ...       NaN       NaN       NaN      NaN       NaN
# 4   NaN  NaN  NaN  NaN  ...       NaN       NaN       NaN      NaN       NaN
# 5   NaN  NaN  NaN  NaN  ...       NaN       NaN       NaN      NaN       NaN
# 6   NaN  NaN  NaN  NaN  ...       NaN       NaN       NaN      NaN       NaN
# 7   NaN  NaN  NaN  NaN  ...       NaN       NaN       NaN      NaN       NaN
# 8   NaN  NaN  NaN  NaN  ...       NaN       NaN       NaN      NaN       NaN
# 9   NaN  NaN  NaN  NaN  ...  0.000003  0.000004  0.000011  0.00001  0.000016
# 10  NaN  NaN  NaN  NaN  ...       NaN       NaN       NaN      NaN       NaN
# 11  NaN  NaN  NaN  NaN  ...       NaN       NaN       NaN      NaN       NaN
#
#         1900      2000      2100      2200      2300
# 0   0.000007  0.000011  0.000019  0.000027  0.000036
# 1        NaN       NaN       NaN       NaN       NaN
# 2        NaN       NaN       NaN       NaN       NaN
# 3        NaN       NaN       NaN       NaN       NaN
# 4        NaN       NaN       NaN       NaN       NaN
# 5        NaN       NaN       NaN       NaN       NaN
# 6        NaN       NaN       NaN       NaN       NaN
# 7        NaN       NaN       NaN       NaN       NaN
# 8        NaN       NaN       NaN       NaN       NaN
# 9   0.000023  0.000033  0.000059  0.000066  0.000116
# 10       NaN       NaN       NaN       NaN       NaN
# 11       NaN       NaN       NaN       NaN       NaN
#
# [12 rows x 29 columns]

# %%
temp = list(range(100, 2300+1, 100))

for i in range(len(match)):
    mat = match.at[i, 'Formula']
    print(mat+' conducts at')
    diff = []
    for j, t in enumerate(temp):
        d = match.at[i, str(t)]
        diff.append(d)
        if np.isnan(d) == False:
            print(str(temp[j])+'K: '+str(d))
    if np.isnan(np.array(diff)).all() == True:
            print('never')
# Out:
# Li3ClO conducts at
# 1800K: 3.103e-06
# 1900K: 6.707e-06
# 2000K: 1.105e-05
# 2100K: 1.941e-05
# 2200K: 2.683e-05
# 2300K: 3.601e-05
# Li2CN2 conducts at
# never
# LiC conducts at
# 800K: 2.472e-05
# LiBr conducts at
# never
# BaLiF3 conducts at
# never
# KLiS conducts at
# never
# Li3BrO conducts at
# never
# Li2ZrF6 conducts at
# never
# RbLiS conducts at
# never
# LiSiBO4 conducts at
# 1300K: 1.621e-06
# 1400K: 3.354e-06
# 1500K: 3.647e-06
# 1600K: 1.074e-05
# 1700K: 1.031e-05
# 1800K: 1.609e-05
# 1900K: 2.276e-05
# 2000K: 3.343e-05
# 2100K: 5.889e-05
# 2200K: 6.631e-05
# 2300K: 0.0001165
# LiN3 conducts at
# never
# LiF conducts at
# never

# %% [markdown]
# 10 new candidates pass the screening criteria. Only 2 are ionic conductors at some temperature. All the other 8 are insulators at all T.

# %% [markdown]
# ### Literature review

# %% [markdown]
# LiC: nothing found.

# %% [markdown]
# LiSiBO4: discovered using unspervised learning methods on diffraction patterns (https://www.nature.com/articles/s41467-019-13214-1)

# %%
overlap1 = pd.merge(c, c_dos, how='inner', on=['material_id'])
overlap2 = pd.merge(c, u_plus, how='inner', on=['material_id'])
overlap3 = pd.merge(c_dos, u_plus, how='inner', on=['material_id'])
overlap4 = pd.merge(c_pbc, u_plus, how='inner', on=['material_id'])
overlap5 = pd.merge(c_pbc, c, how='inner', on=['material_id'])
overlap6 = pd.merge(c_pbc, c_dos, how='inner', on=['material_id'])

# %%
overlap1
# Out:
# Empty DataFrame
# Columns: [material_id, formula_pretty_reduced, 0.2, 0.5, Dimension 1, Dimension 2, Formula, σ(RT)(S cm-1), Conductor?]
# Index: []

# %%
overlap2
# Out:
# Empty DataFrame
# Columns: [material_id, formula_pretty_reduced_x, 0.2, 0.5, formula_pretty_reduced_y, d_fav]
# Index: []

# %%
overlap3
# Out:
# Empty DataFrame
# Columns: [Dimension 1, Dimension 2, Formula, material_id, σ(RT)(S cm-1), Conductor?, formula_pretty_reduced, d_fav]
# Index: []

# %%
overlap4
# Out:
#   material_id formula_pretty_reduced_x   298_tot formula_pretty_reduced_y  \
# 0   mp-504354               LiBi(PO3)4  1.788745               LiBi(PO3)4
#
#        d_fav
# 0  12.201742

# %%
overlap5
# Out:
#   material_id formula_pretty_reduced_x   298_tot formula_pretty_reduced_y  \
# 0   mp-772535                LiNb13O33  1.402210                LiNb13O33
# 1   mp-696129             Li10Si(PS6)2  1.880669             Li10Si(PS6)2
# 2   mp-696128             Li10Ge(PS6)2  1.963787             Li10Ge(PS6)2
# 3   mp-552663                LiScAs2O7  0.952264                LiScAs2O7
# 4    mp-40189               BaLiLaTeO6  1.433100               BaLiLaTeO6
#
#         0.2       0.5
# 0 -7.303432 -7.303432
# 1 -2.550960       NaN
# 2 -2.276746       NaN
# 3 -1.097430       NaN
# 4 -1.945770 -1.945770

# %%
overlap6
# Out:
# Empty DataFrame
# Columns: [material_id, formula_pretty_reduced, 298_tot, Dimension 1, Dimension 2, Formula, σ(RT)(S cm-1), Conductor?]
# Index: []

# %% [markdown]
# Overlap for some, but none are actually ionic conductors.
